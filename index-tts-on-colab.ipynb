# %%
# !apt install ffmpeg
# !pip install ffmpeg torch torchaudio deepspeed "huggingface_hub[cli]"

# !git clone https://github.com/index-tts/index-tts.git
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Collecting deepspeed
#   Downloading deepspeed-0.17.5.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deepspeed) (0.8.1)
# Collecting hjson (from deepspeed)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from deepspeed) (1.1.1)
# Collecting ninja (from deepspeed)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deepspeed) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from deepspeed) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from deepspeed) (4.67.1)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from deepspeed) (12.575.51)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (1.1.8)
# Collecting InquirerPy==0.3.4 (from huggingface_hub[cli])
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface_hub[cli])
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.51)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed) (0.4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (2025.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.1 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.9 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 19.4 MB/s eta 0:00:00
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: ffmpeg, deepspeed
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=5f591ed8db6de5ad6966ceb0f041ea8a9f67a2270281725f93b12abbb8966b1d
#   Stored in directory: /root/.cache/pip/wheels/26/21/0c/c26e09dff860a9071683e279445262346e008a9a1d2142c4ad
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.17.5-py3-none-any.whl size=1726485 sha256=758cfcb87640d918ce133d4216d8de12b38937a323f93912297670d817352d7d
#   Stored in directory: /root/.cache/pip/wheels/59/3a/01/079b5f719e6fd280d79f210f54f5e5c6cbc7b956c9905ea274
# Successfully built ffmpeg deepspeed
# Installing collected packages: hjson, ffmpeg, pfzy, ninja, InquirerPy, deepspeed
# Successfully installed InquirerPy-0.3.4 deepspeed-0.17.5 ffmpeg-1.4 hjson-3.1.0 ninja-1.13.0 pfzy-0.3.4
# Cloning into 'index-tts'...
# remote: Enumerating objects: 755, done.
# remote: Counting objects: 100% (374/374), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 755 (delta 299), reused 217 (delta 217), pack-reused 381 (from 2)
# Receiving objects: 100% (755/755), 21.08 MiB | 23.59 MiB/s, done.
# Resolving deltas: 100% (372/372), done.

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落

# %%
# 安装 index-tts 的过程中，环境会报错，需要重新启动
# 启动后还需要重新执行
# 重新执行就可以成功安装，正常使用
# !pip install -e index-tts
# Out:
# Obtaining file:///content/index-tts
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (2.8.0+cu126)
# Collecting transformers==4.36.2 (from indextts==0.1.4)
#   Downloading transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (1.10.1)
# Collecting tokenizers==0.15.0 (from indextts==0.1.4)
#   Downloading tokenizers-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: einops==0.8.1 in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (0.8.1)
# Collecting matplotlib==3.8.2 (from indextts==0.1.4)
#   Downloading matplotlib-3.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (2.3.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (0.2.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from indextts==0.1.4) (2.0.2)
# Collecting WeTextProcessing (from indextts==0.1.4)
#   Downloading WeTextProcessing-1.0.4.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (1.4.9)
# Collecting numpy (from indextts==0.1.4)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->indextts==0.1.4) (2.9.0.post0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers==0.15.0->indextts==0.1.4) (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.2->indextts==0.1.4) (3.19.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.2->indextts==0.1.4) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.2->indextts==0.1.4) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.2->indextts==0.1.4) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.2->indextts==0.1.4) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.2->indextts==0.1.4) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->indextts==0.1.4) (3.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->indextts==0.1.4) (5.9.5)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (1.16.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->indextts==0.1.4) (1.1.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->indextts==0.1.4) (4.9.3)
# Collecting pynini==2.1.6 (from WeTextProcessing->indextts==0.1.4)
#   Downloading pynini-2.1.6-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from WeTextProcessing->indextts==0.1.4) (6.5.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers==0.15.0->indextts==0.1.4) (1.1.8)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->indextts==0.1.4) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->indextts==0.1.4) (4.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.2->indextts==0.1.4) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36.2->indextts==0.1.4) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36.2->indextts==0.1.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36.2->indextts==0.1.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36.2->indextts==0.1.4) (2025.8.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->indextts==0.1.4) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa->indextts==0.1.4) (1.17.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.2->indextts==0.1.4) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.2->indextts==0.1.4) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->indextts==0.1.4) (2.22)
# Downloading matplotlib-3.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 111.8 MB/s eta 0:00:00
# Downloading tokenizers-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 93.9 MB/s eta 0:00:00
# Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 110.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 110.1 MB/s eta 0:00:00
# Downloading WeTextProcessing-1.0.4.1-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 84.6 MB/s eta 0:00:00
# Downloading pynini-2.1.6-cp312-cp312-manylinux_2_28_x86_64.whl (154.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 MB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: indextts
#   Building editable for indextts (pyproject.toml) ... done
#   Created wheel for indextts: filename=indextts-0.1.4-0.editable-py3-none-any.whl size=11817 sha256=a74e564c5739a3764ce70c03fe749851adaed2f52598d5f2cb55216c8a6f3cb9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_bsvtd9a/wheels/e5/e5/0a/16ed1a85f3824813778778ea25a296992c1e3c4beaecf922b1
# Successfully built indextts
# Installing collected packages: pynini, numpy, WeTextProcessing, tokenizers, matplotlib, transformers, indextts
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.4
#     Uninstalling tokenizers-0.21.4:
#       Successfully uninstalled tokenizers-0.21.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.55.4
#     Uninstalling transformers-4.55.4:
#       Successfully uninstalled transformers-4.55.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed WeTextProcessing-1.0.4.1 indextts-0.1.4 matplotlib-3.8.2 numpy-1.26.4 pynini-2.1.6 tokenizers-0.15.0 transformers-4.36.2

# %%
# !hf download IndexTeam/IndexTTS-1.5 \
  config.yaml bigvgan_discriminator.pth bigvgan_generator.pth bpe.model dvae.pth gpt.pth unigram_12000.vocab \
  --local-dir index-tts/checkpoints
# Out:
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]Downloading 'bigvgan_generator.pth' to 'index-tts/checkpoints/.cache/huggingface/download/T7MAeDN3QnT7K91CJaMdYrAx26o=.a2458834d8277e76eb8614c9751b5e8eaa0474eab706f0ecfafcb600023133ed.incomplete'
# Downloading 'bigvgan_discriminator.pth' to 'index-tts/checkpoints/.cache/huggingface/download/rP61RaCCq8JUX_UrFOklpHIyM0A=.46e1f6277f7239363d2393f2f9fe36902cf8995e4acc0ba67ed25a025dbd02f0.incomplete'
# Downloading 'gpt.pth' to 'index-tts/checkpoints/.cache/huggingface/download/_7f-xidG2lZwkbGRwdGaUEGM9-w=.44460b820a8afd58f68f3d3e69113e7900c8730bf519ecf158c081f2b8991240.incomplete'
# Downloading 'config.yaml' to 'index-tts/checkpoints/.cache/huggingface/download/_ouC4VcfA9-o6nAiMaExMJW7X2A=.b6a91940605aa11f6360103d05b2a110da1e2fea.incomplete'
# Downloading 'unigram_12000.vocab' to 'index-tts/checkpoints/.cache/huggingface/download/DyI2HlpVtENU6daLhCfFZFW3_ss=.337ffb4197e69c3d7aa57efe2022bbde577b951d.incomplete'
# Downloading 'bpe.model' to 'index-tts/checkpoints/.cache/huggingface/download/Gxtyhw1DNb_863rgFQ-g37D7LQI=.b2a5ce8090d32da3642cc4f81fdc996376bc6dd3f4cd5e3d165f71120d9f2bc8.incomplete'
#
# config.yaml: 2.49kB [00:00, 5.43MB/s]
# Download complete. Moving file to index-tts/checkpoints/config.yaml
#
# unigram_12000.vocab: 94.7kB [00:00, 6.06MB/s]
# Download complete. Moving file to index-tts/checkpoints/unigram_12000.vocab
#
# bigvgan_generator.pth:   0% 0.00/536M [00:00<?, ?B/s]
#
# bigvgan_discriminator.pth:   0% 0.00/1.65G [00:00<?, ?B/s]
#
#
# gpt.pth:   0% 0.00/1.17G [00:00<?, ?B/s]
#
#
#
# bpe.model:   0% 0.00/476k [00:00<?, ?B/s]Downloading 'dvae.pth' to 'index-tts/checkpoints/.cache/huggingface/download/Eo-uOl65TcDqOo9qbdw9EufkiwQ=.69e841bf8cd97a32806ea8a439c50017c991ac9e8bb795db89ec47828cae4d5d.incomplete'
#
#
#
#
#
# dvae.pth:   0% 0.00/243M [00:00<?, ?B/s]
#
#
#
# bpe.model: 100% 476k/476k [00:00<00:00, 920kB/s]
# Download complete. Moving file to index-tts/checkpoints/bpe.model
#
#
#
#
#
# dvae.pth:   1% 3.15M/243M [00:00<00:47, 5.06MB/s]
#
# bigvgan_discriminator.pth:   0% 822k/1.65G [00:01<43:38, 630kB/s]
#
#
#
#
# dvae.pth:  17% 42.2M/243M [00:03<00:14, 13.7MB/s]
#
#
# gpt.pth:   0% 698k/1.17G [00:03<1:33:20, 209kB/s]
#
#
#
#
# dvae.pth:  45% 109M/243M [00:08<00:10, 13.4MB/s]
#
#
# gpt.pth:   6% 67.8M/1.17G [00:09<02:12, 8.30MB/s]
#
#
# gpt.pth:  12% 135M/1.17G [00:11<01:15, 13.7MB/s]
#
#
# gpt.pth:  17% 202M/1.17G [00:12<00:41, 23.1MB/s]
#
#
# gpt.pth:  23% 269M/1.17G [00:12<00:24, 36.3MB/s]
#
# bigvgan_discriminator.pth:   4% 67.8M/1.65G [00:13<05:04, 5.20MB/s]
#
#
# gpt.pth:  29% 336M/1.17G [00:13<00:19, 43.4MB/s]
#
#
# gpt.pth:  34% 403M/1.17G [00:15<00:20, 37.0MB/s]
#
#
#
#
# dvae.pth:  45% 109M/243M [00:19<00:10, 13.4MB/s]
#
#
# gpt.pth:  40% 470M/1.17G [00:19<00:25, 27.0MB/s]
#
#
# gpt.pth:  46% 537M/1.17G [00:20<00:16, 37.5MB/s]
#
#
# gpt.pth:  52% 604M/1.17G [00:20<00:10, 52.5MB/s]
#
# bigvgan_discriminator.pth:   8% 135M/1.65G [00:20<03:40, 6.89MB/s]
#
# bigvgan_discriminator.pth:  12% 202M/1.65G [00:21<01:59, 12.1MB/s]
#
# bigvgan_discriminator.pth:  16% 269M/1.65G [00:23<01:28, 15.6MB/s]
#
#
# gpt.pth:  57% 671M/1.17G [00:23<00:15, 32.9MB/s]
#
# bigvgan_discriminator.pth:  20% 336M/1.65G [00:24<00:58, 22.4MB/s]
#
#
#
#
# dvae.pth:  72% 176M/243M [00:24<00:10, 6.26MB/s]
#
# bigvgan_discriminator.pth:  24% 403M/1.65G [00:25<00:44, 28.4MB/s]
#
#
# gpt.pth:  63% 738M/1.17G [00:25<00:12, 34.0MB/s]
#
#
#
#
# dvae.pth: 100% 243M/243M [00:28<00:00, 8.44MB/s]
# Download complete. Moving file to index-tts/checkpoints/dvae.pth
#
#
#
# gpt.pth:  69% 806M/1.17G [00:28<00:12, 28.5MB/s]
#
#
# gpt.pth:  75% 873M/1.17G [00:30<00:09, 31.6MB/s]
#
# bigvgan_discriminator.pth:  28% 470M/1.65G [00:30<00:56, 20.8MB/s]
#
# bigvgan_discriminator.pth:  33% 537M/1.65G [00:36<01:05, 17.0MB/s]
#
# bigvgan_discriminator.pth:  41% 671M/1.65G [00:40<00:44, 22.1MB/s]
# bigvgan_generator.pth:  13% 67.0M/536M [00:40<04:41, 1.67MB/s]
#
# bigvgan_discriminator.pth:  45% 738M/1.65G [00:41<00:33, 27.1MB/s]
#
# bigvgan_discriminator.pth:  49% 806M/1.65G [00:46<00:41, 20.6MB/s]
#
#
# gpt.pth:  80% 940M/1.17G [00:46<00:21, 10.5MB/s]
#
# bigvgan_discriminator.pth:  53% 873M/1.65G [00:47<00:30, 25.8MB/s]
# bigvgan_generator.pth:  25% 134M/536M [00:47<02:06, 3.18MB/s]
#
# bigvgan_discriminator.pth:  57% 940M/1.65G [00:48<00:23, 30.9MB/s]
#
# bigvgan_discriminator.pth:  61% 1.01G/1.65G [00:49<00:16, 38.2MB/s]
# bigvgan_generator.pth:  37% 201M/536M [00:49<01:00, 5.50MB/s]
#
#
# gpt.pth:  86% 1.01G/1.17G [00:50<00:13, 12.3MB/s]
#
# bigvgan_discriminator.pth:  65% 1.07G/1.65G [00:50<00:13, 42.8MB/s]
#
# bigvgan_discriminator.pth:  69% 1.14G/1.65G [00:51<00:10, 49.2MB/s]
# bigvgan_generator.pth:  50% 268M/536M [00:51<00:32, 8.31MB/s]
#
# bigvgan_discriminator.pth:  73% 1.21G/1.65G [00:52<00:08, 50.4MB/s]
# bigvgan_generator.pth:  62% 335M/536M [00:52<00:16, 12.0MB/s]
#
#
# gpt.pth:  92% 1.07G/1.17G [00:53<00:06, 14.2MB/s]
#
#
# gpt.pth:  97% 1.14G/1.17G [00:53<00:01, 19.7MB/s]
#
#
# gpt.pth: 100% 1.17G/1.17G [00:53<00:00, 21.7MB/s]
# Download complete. Moving file to index-tts/checkpoints/gpt.pth
#
# bigvgan_generator.pth:  75% 402M/536M [00:54<00:08, 15.5MB/s]
# bigvgan_generator.pth:  87% 469M/536M [00:55<00:03, 21.3MB/s]
# bigvgan_generator.pth: 100% 536M/536M [00:55<00:00, 9.70MB/s]
# Download complete. Moving file to index-tts/checkpoints/bigvgan_generator.pth
#
#
# bigvgan_discriminator.pth:  77% 1.27G/1.65G [00:56<00:11, 33.1MB/s]
#
# bigvgan_discriminator.pth:  81% 1.34G/1.65G [00:56<00:07, 43.6MB/s]
#
# bigvgan_discriminator.pth:  85% 1.41G/1.65G [00:56<00:04, 53.5MB/s]
#
# bigvgan_discriminator.pth:  89% 1.48G/1.65G [01:06<00:10, 17.4MB/s]
#
# bigvgan_discriminator.pth:  92% 1.52G/1.65G [01:09<00:08, 16.5MB/s]
#
# bigvgan_discriminator.pth:  96% 1.58G/1.65G [01:11<00:03, 21.5MB/s]
#
# bigvgan_discriminator.pth: 100% 1.65G/1.65G [01:11<00:00, 23.2MB/s]
# Download complete. Moving file to index-tts/checkpoints/bigvgan_discriminator.pth
# Fetching 7 files: 100% 7/7 [01:11<00:00, 10.23s/it]
# /content/index-tts/checkpoints

# %%
# 修改 indextts/webui.py 在最后的启动入口加上 share = True
# 进入终端
# 执行
# cd indextts
# python webui.py

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/download/2025.8.0/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
# !/content/cloudflared-linux-amd64 tunnel --url localhost:7860
